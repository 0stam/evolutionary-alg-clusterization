# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
points = np.loadtxt('./data/rings.csv', delimiter=",")

# %%
clusters = np.loadtxt("./data/result.txt")

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(points[:, 0], points[:, 1], c=clusters, alpha=0.7, cmap='viridis')
plt.colorbar()

# %%
unique, counts = np.unique(clusters, return_counts=True)
np.asarray((unique, counts)).T
# Out:
# array([[  1., 277.],
#        [  2., 281.],
#        [  3., 442.]])
